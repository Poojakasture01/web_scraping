# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\pooja\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pooja\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from os import name
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd



link = 'https://www.talabat.com/uae/restaurant/621796/pizza-di-rocco-jumeirah-lakes-towers--jlt?aid=1308'
r = requests.get(link)
soup = BeautifulSoup(r.text, 'html.parser')

#Scraping data under script tag with id='__NEXT_DATA__'
s = soup.find('script', id='__NEXT_DATA__')

#JSON Formatting
json = json.loads(s.string)
node1 = json['props']['pageProps']['initialMenuState']['restaurant']
node2 = json['props']['pageProps']['initialMenuState']['menuData']['items']

#Creating tables for displaying necessary fields

menu = []
for i in range(len(node2)):
  menu.append(node2[i]['name'])

table = {}
table["restaurant_name"] = [node1["name"]]
table["restaurant_logo"] = [node1["logo"]]
table["latitude"] = [node1["latitude"]]
table["longitude"] = [node1["longitude"]]
table["cuisine_tags"] = [node1["cuisineString"]]
table["menu_items"] = []
table.update({"menu_items": [','.join(map(str, menu))]})

menu_table = [{} for i in range(len(node2))]
for i in range(len(node2)):
  menu_table[i]["item_name"] = [node2[i]["name"]]
  menu_table[i]["item_description"] = [node2[i]["description"]]
  menu_table[i]["item_price"] = [node2[i]["price"]]
  menu_table[i]["item_image"] = [node2[i]["originalImage"]]


#Printing tables
df1 = pd. DataFrame(data=table)
df1 = (df1. T)
print(df1)

df = pd. DataFrame(data=menu_table)
df = (df. T)
print(df)



# Final JSON data, which connects restaurant table and menu table
final = table
final.update({"menu_items_details": menu_table})
# Out:
#                                                                  0
# restaurant_name                                     Pizza Di Rocco
# restaurant_logo  https://images.deliveryhero.io/image/talabat/r...
# latitude                                                25.0650915
# longitude                                               55.1387907
# cuisine_tags                                 Pizza, Pasta, Italian
# menu_items       Meal for 2,Margherita,Tender Chicken Strips,Ba...
#                                                                  0   \
# item_name                                              [Meal for 2]
# item_description  [Any 2 Pizzas, Any Appetizer, 2 Soft Drinks. S...
# item_price                                                     [99]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  1   \
# item_name                                              [Margherita]
# item_description  [Tomato sauce, fior di latte mozzarella, fresh...
# item_price                                                     [46]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  2   \
# item_name                                   [Tender Chicken Strips]
# item_description  [Juicy, tender and succulent breaded strips, s...
# item_price                                                     [32]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  3   \
# item_name                                  [Banana Caramel Pudding]
# item_description  [A creamy pile of deliciousness made with cara...
# item_price                                                     [28]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  4   \
# item_name                                        [Quattro Formaggi]
# item_description  [Tomato sauce, fior di latte mozzarella, gorgo...
# item_price                                                     [55]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  5   \
# item_name                                            [Meal for One]
# item_description               [Any Pizza, Appetiser & Soft Drink!]
# item_price                                                     [65]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  6   \
# item_name                                              [Meal for 2]
# item_description  [Any 2 Pizzas, Any Appetizer, 2 Soft Drinks. S...
# item_price                                                     [99]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  7   \
# item_name                                   [Appetiser Sharing Box]
# item_description                      [Choice of any 3 Appetisers!]
# item_price                                                     [72]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  8   \
# item_name                                             [BBQ Brisket]
# item_description  [Tomato sauce, fior di latte mozzarella, homem...
# item_price                                                     [58]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  9   ...  \
# item_name                    [Oven-baked Garlic Bread & Mozzarella]  ...
# item_description  [Rocco`s classic dough baked with homemade roa...  ...
# item_price                                                     [28]  ...
# item_image        [https://images.deliveryhero.io/image/talabat/...  ...
#
#                                                                  88  \
# item_name                                [Belgian Chocolate Mousse]
# item_description  [Thick, creamy and deliciously chocolatey. Mad...
# item_price                                                     [23]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  89  \
# item_name                                      [Fresh Lemon & Mint]
# item_description                 [Freshly squeezed lemon with mint]
# item_price                                                     [19]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  90  \
# item_name                                               [Coca Cola]
# item_description                                                 []
# item_price                                                      [9]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  91  \
# item_name                                        [Coca Cola (Zero)]
# item_description                                                 []
# item_price                                                      [9]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  92  \
# item_name                                                  [Sprite]
# item_description                                                 []
# item_price                                                      [9]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  93  \
# item_name                                             [Sprite Zero]
# item_description                                                 []
# item_price                                                      [9]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  94  \
# item_name                                            [Fanta Orange]
# item_description                                                 []
# item_price                                                      [9]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  95  \
# item_name                                            [Arwa (500ml)]
# item_description                                                 []
# item_price                                                      [3]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  96  \
# item_name                               [Acqua Panna Small (250ml)]
# item_description                                                 []
# item_price                                                      [8]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
#                                                                  97
# item_name                            [San Pellegrino Small (250ml)]
# item_description                                                 []
# item_price                                                      [9]
# item_image        [https://images.deliveryhero.io/image/talabat/...
#
# [4 rows x 98 columns]

# %%
df1.head()
# Out:
#                                                                  0
# restaurant_name                                     Pizza Di Rocco
# restaurant_logo  https://images.deliveryhero.io/image/talabat/r...
# latitude                                                25.0650915
# longitude                                               55.1387907
# cuisine_tags                                 Pizza, Pasta, Italian

# %%
 df3=df1.transpose()

# %%
df3.head()
# Out:
#   restaurant_name                                    restaurant_logo  \
# 0  Pizza Di Rocco  https://images.deliveryhero.io/image/talabat/r...
#
#      latitude   longitude           cuisine_tags  \
# 0  25.0650915  55.1387907  Pizza, Pasta, Italian
#
#                                           menu_items
# 0  Meal for 2,Margherita,Tender Chicken Strips,Ba...
